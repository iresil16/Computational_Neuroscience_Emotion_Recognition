# %% [markdown]
# # PREPROCESSING THE DATASET

# %%
import nilearn as nil
import nibabel as nib
import numpy as np
import pandas as pd
import os
import matplotlib
import matplotlib.pyplot as plt
from nilearn import plotting, surface, datasets, input_data, decomposition
from scipy.stats import pearsonr, spearmanr
from tqdm import tqdm # For having progressbar during loops
from nitime.timeseries import TimeSeries
from nitime.analysis import FilterAnalyzer
from sklearn.decomposition import PCA
from nilearn.connectome import ConnectivityMeasure
from matplotlib import colors
from matplotlib import patches
from pycirclize import Circos
import sys
import networkx as nx
import community as community_louvain
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %% [markdown]
# ## Descovering the dataset

# %%
from nilearn import image

# Load the fMRI file for subject 1
fmri_img = image.load_img('/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-01/func/sub-01_task-fe_bold.nii.gz')

# Display image information
print(fmri_img.shape)  # Returns the shape (dimensions x, y, z, number of volumes)
print(fmri_img.header.get_zooms())
print(fmri_img.header.get_xyzt_units())
# Out:
# (128, 128, 36, 200)
# (1.796875, 1.796875, 4.0, 3.000001)
# ('mm', 'sec')
# <class 'numpy.ndarray'>
# (128, 128, 36, 200)

# %% [markdown]
# # RESHAPE DEL DATASET

# %% [markdown]
# ## load the brain mask and the atlas

# %%
mask_path='/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/functional_connectivity/data-2/group_mask/' # Path to the folder with the brain mask
filename='group_mask.nii.gz' # List of the subjects

mask_ = nib.load(mask_path+filename) # Load the nii.gz file of the subject
mask_header = mask_.header # Subject's header
mask_affine = mask_.affine # Subject's affine
mask = mask_.get_fdata() # Get the numpy version of the nii.gz file
print(mask.shape) # x*y*z*time
n_vox_mask = np.sum(mask==1) # Number of voxels within the mask
# Out:
# (52, 62, 52)

# %%
which_atlas = 'glasser' # Chose the atlas
main_path='/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/functional_connectivity/data-2/atlas/' # Path to the folder with the atlas
filename = 'glasser_MNI152NLin6Asym_labels_p20_resamp.nii.gz'
atlas_labels_file = 'glasser_labels.csv'
delimiter = ','

atlas_ = nib.load(main_path+'/'+which_atlas+'/'+filename) # Load the nii.gz file of the subject
atlas_header = atlas_.header # Subject's header
atlas_affine = atlas_.affine # Subject's affine
atlas = atlas_.get_fdata() # Get the numpy version of the nii.gz file
print(atlas.shape) # x*y*z*time

# Labels
atlas_labels = pd.read_csv(main_path+'/'+which_atlas+'/'+atlas_labels_file, delimiter=delimiter)
print(atlas.min(), atlas.max())
# Out:
# (52, 62, 52)
# 0.0 360.0

# %%
# Plot the atlas
plotting.plot_roi(atlas_, title=which_atlas+' atlas', display_mode='ortho')

# %% [markdown]
# ## load the subjects

# %%
import nibabel as nib
import os

# Define the base directory where the subject data is stored
base_path = '/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/'

# Initialize a list to store data for all subjects
subjects_data = []

# Loop through subjects
for i in range(1, 41):
    # Format the subject ID as 'sub-01', 'sub-02', ..., 'sub-40'
    subj_id = f"sub-{i:02d}"
    
    # Construct the full path to the subject's fMRI file
    fmri_path = os.path.join(base_path, subj_id, 'func', f'{subj_id}_task-fe_bold.nii.gz')
    
    # Check if the fMRI file exists
    if os.path.exists(fmri_path):
        # Load the NIfTI image using nibabel
        sub_ = nib.load(fmri_path)
        
        # Create a dictionary with relevant subject information
        subject_dict = {
            'id': subj_id,                        # Subject ID
            'data': sub_.get_fdata(),             # 4D fMRI data as a NumPy array
            'header': sub_.header,                # Image header metadata
            'affine': sub_.affine,                # Affine transformation matrix
            'path': fmri_path                     # File path
        }
        
        # Print confirmation that the subject was loaded
        print(f"{subj_id} loaded, shape: {subject_dict['data'].shape}")
        
        # Append the subject's data to the list
        subjects_data.append(subject_dict)
    else:
        # Print a warning if the file was not found
        print(f"File not found: {fmri_path}")
# Out:
# sub-01 loaded, shape: (128, 128, 36, 200)
# sub-02 loaded, shape: (128, 128, 36, 200)
# sub-03 loaded, shape: (128, 128, 36, 200)
# sub-04 loaded, shape: (128, 128, 36, 200)
# sub-05 loaded, shape: (128, 128, 36, 200)
# sub-06 loaded, shape: (128, 128, 36, 200)
# sub-07 loaded, shape: (128, 128, 36, 200)
# sub-08 loaded, shape: (128, 128, 36, 200)
# sub-09 loaded, shape: (128, 128, 36, 200)
# sub-10 loaded, shape: (128, 128, 36, 200)
# sub-11 loaded, shape: (128, 128, 36, 200)
# sub-12 loaded, shape: (128, 128, 36, 200)
# sub-13 loaded, shape: (128, 128, 36, 200)
# sub-14 loaded, shape: (128, 128, 36, 200)
# sub-15 loaded, shape: (128, 128, 36, 200)
# sub-16 loaded, shape: (128, 128, 36, 200)
# sub-17 loaded, shape: (128, 128, 36, 200)
# sub-18 loaded, shape: (128, 128, 36, 200)
# sub-19 loaded, shape: (128, 128, 36, 200)
# sub-20 loaded, shape: (128, 128, 36, 200)
# sub-21 loaded, shape: (128, 128, 36, 200)
# sub-22 loaded, shape: (128, 128, 36, 200)
# sub-23 loaded, shape: (128, 128, 36, 200)
# sub-24 loaded, shape: (128, 128, 36, 200)
# sub-25 loaded, shape: (128, 128, 36, 200)
# sub-26 loaded, shape: (128, 128, 36, 200)
# sub-27 loaded, shape: (128, 128, 36, 200)
# sub-28 loaded, shape: (128, 128, 36, 200)
# sub-29 loaded, shape: (128, 128, 36, 200)
# sub-30 loaded, shape: (128, 128, 36, 200)
# sub-31 loaded, shape: (128, 128, 36, 200)
# sub-32 loaded, shape: (128, 128, 36, 200)
# sub-33 loaded, shape: (128, 128, 36, 200)
# sub-34 loaded, shape: (128, 128, 36, 200)
# sub-35 loaded, shape: (128, 128, 36, 200)
# sub-36 loaded, shape: (128, 128, 36, 200)
# sub-37 loaded, shape: (128, 128, 36, 200)
# sub-38 loaded, shape: (128, 128, 36, 200)
# sub-39 loaded, shape: (128, 128, 36, 200)
# sub-40 loaded, shape: (128, 128, 36, 200)

# %% [markdown]
# ## resamble the data to the dimention of the atlas

# %%
from nilearn.image import resample_to_img

# Loop through each subject in the loaded subject data
for subject in subjects_data:
    # Resample the subject's functional image to match the resolution and space of the atlas
    resampled_img = resample_to_img(
        nib.Nifti1Image(subject['data'], subject['affine']),  # Original subject image
        atlas_                                                # Target image (e.g., an atlas)
    )
    
    save_path = os.path.join(base_path, subject['id'], 'func', f"{subject['id']}_resampled_fe.nii.gz" )
    
    # Save the resampled image to disk
    resampled_img.to_filename(save_path)

# %% [markdown]
# ## SPLIT THE DATA

# %%
from nilearn import image

# Load the fMRI file for subject 1
fmri_img = image.load_img('/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-01/func/sub-01_resampled_fe.nii.gz')

# Display image information
print(fmri_img.shape)
# Out:
# (52, 62, 52, 200)

# %% [markdown]
# ## creating the .tsv file

# %%
base_path = '/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/'

subjects_data = []

for i in range(1, 41):
    subj_id = f"sub-{i:02d}"
    fmri_path = os.path.join(base_path, subj_id, 'func', f'{subj_id}_resampled_fe.nii.gz')
    
    
    if os.path.exists(fmri_path):
        sub_ = nib.load(fmri_path)
        subject_dict = {
            'id': subj_id,
            'data': sub_.get_fdata(),
            'header': sub_.header,
            'affine': sub_.affine,
            'path': fmri_path
        }
        print(f"{subj_id} loaded, shape: {subject_dict['data'].shape}")
        subjects_data.append(subject_dict)
    else:
        print(f"File non trovato: {fmri_path}")
# Out:
# sub-01 loaded, shape: (52, 62, 52, 200)
# sub-02 loaded, shape: (52, 62, 52, 200)
# sub-03 loaded, shape: (52, 62, 52, 200)
# sub-04 loaded, shape: (52, 62, 52, 200)
# sub-05 loaded, shape: (52, 62, 52, 200)
# sub-06 loaded, shape: (52, 62, 52, 200)
# sub-07 loaded, shape: (52, 62, 52, 200)
# sub-08 loaded, shape: (52, 62, 52, 200)
# sub-09 loaded, shape: (52, 62, 52, 200)
# sub-10 loaded, shape: (52, 62, 52, 200)
# sub-11 loaded, shape: (52, 62, 52, 200)
# sub-12 loaded, shape: (52, 62, 52, 200)
# sub-13 loaded, shape: (52, 62, 52, 200)
# sub-14 loaded, shape: (52, 62, 52, 200)
# sub-15 loaded, shape: (52, 62, 52, 200)
# sub-16 loaded, shape: (52, 62, 52, 200)
# sub-17 loaded, shape: (52, 62, 52, 200)
# sub-18 loaded, shape: (52, 62, 52, 200)
# sub-19 loaded, shape: (52, 62, 52, 200)
# sub-20 loaded, shape: (52, 62, 52, 200)
# sub-21 loaded, shape: (52, 62, 52, 200)
# sub-22 loaded, shape: (52, 62, 52, 200)
# sub-23 loaded, shape: (52, 62, 52, 200)
# sub-24 loaded, shape: (52, 62, 52, 200)
# sub-25 loaded, shape: (52, 62, 52, 200)
# sub-26 loaded, shape: (52, 62, 52, 200)
# sub-27 loaded, shape: (52, 62, 52, 200)
# sub-28 loaded, shape: (52, 62, 52, 200)
# sub-29 loaded, shape: (52, 62, 52, 200)
# sub-30 loaded, shape: (52, 62, 52, 200)
# sub-31 loaded, shape: (52, 62, 52, 200)
# sub-32 loaded, shape: (52, 62, 52, 200)
# sub-33 loaded, shape: (52, 62, 52, 200)
# sub-34 loaded, shape: (52, 62, 52, 200)
# sub-35 loaded, shape: (52, 62, 52, 200)
# sub-36 loaded, shape: (52, 62, 52, 200)
# sub-37 loaded, shape: (52, 62, 52, 200)
# sub-38 loaded, shape: (52, 62, 52, 200)
# sub-39 loaded, shape: (52, 62, 52, 200)
# sub-40 loaded, shape: (52, 62, 52, 200)

# %%
# Table of task conditions (onset, duration, emotion)
events_data = [
    (0,   30, 'calm'),
    (30,  30, 'white_noise'),
    (60,  30, 'afraid'),
    (90,  30, 'white_noise'),
    (120, 30, 'delighted'),
    (150, 30, 'white_noise'),
    (180, 30, 'depressed'),
    (210, 30, 'white_noise'),
    (240, 30, 'excited'),
    (270, 30, 'white_noise'),
    (300, 30, 'delighted'),
    (330, 30, 'white_noise'),
    (360, 30, 'depressed'),
    (390, 30, 'white_noise'),
    (420, 30, 'calm'),
    (450, 30, 'white_noise'),
    (480, 30, 'excited'),
    (510, 30, 'white_noise'),
    (540, 30, 'afraid'),
    (570, 30, 'white_noise'),
]

# Create DataFrame
events_df = pd.DataFrame(events_data, columns=["onset", "duration", "trial_type"])

# Base path for subjects
base_path = "/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/"

# Save .tsv files for all subjects
for i in range(1, 41):
    subj_id = f"sub-{i:02d}"
    tsv_path = os.path.join(base_path, subj_id, "func", f"{subj_id}_task-fe_events.tsv")
    events_df.to_csv(tsv_path, sep="\t", index=False)
    print(f"{tsv_path} salvato.")
# Out:
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-01/func/sub-01_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-02/func/sub-02_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-03/func/sub-03_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-04/func/sub-04_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-05/func/sub-05_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-06/func/sub-06_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-07/func/sub-07_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-08/func/sub-08_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-09/func/sub-09_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-10/func/sub-10_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-11/func/sub-11_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-12/func/sub-12_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-13/func/sub-13_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-14/func/sub-14_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-15/func/sub-15_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-16/func/sub-16_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-17/func/sub-17_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-18/func/sub-18_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-19/func/sub-19_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-20/func/sub-20_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-21/func/sub-21_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-22/func/sub-22_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-23/func/sub-23_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-24/func/sub-24_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-25/func/sub-25_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-26/func/sub-26_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-27/func/sub-27_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-28/func/sub-28_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-29/func/sub-29_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-30/func/sub-30_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-31/func/sub-31_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-32/func/sub-32_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-33/func/sub-33_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-34/func/sub-34_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-35/func/sub-35_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-36/func/sub-36_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-37/func/sub-37_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-38/func/sub-38_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-39/func/sub-39_task-fe_events.tsv salvato.
# /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-40/func/sub-40_task-fe_events.tsv salvato.

# %% [markdown]
# ## split the data in 20 parts

# %%
# Global parameters
TR = 3
vol_per_clip = 30 // TR  # 10 volumes per segment

# Base path
base_path = "/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/"

# Loop over all subjects
for i in range(1, 41):
    subject_id = f"sub-{i:02d}"
    
    # Construct file paths
    func_path = os.path.join(base_path, subject_id, "func", f"{subject_id}_resampled_fe.nii.gz")
    tsv_path = os.path.join(base_path, subject_id, "func", f"{subject_id}_task-fe_events.tsv")
    output_dir = os.path.join(base_path, subject_id, "func", f"{subject_id}_splitted")
    
    # Check if files exist
    if not os.path.exists(func_path):
        print(f"[!] fMRI not found for {subject_id}")
        continue
    if not os.path.exists(tsv_path):
        print(f"[!] TSV not found for {subject_id}")
        continue

    # Create output folder if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Load the fMRI image
    img = nib.load(func_path)
    data = img.get_fdata()
    affine = img.affine
    header = img.header

    # Load events
    events = pd.read_csv(tsv_path, sep='\t')

    # Split and save each segment
    for j, row in events.iterrows():
        onset = int(row['onset'] // TR)  # from seconds to volumes
        label = row['trial_type']
        sub_data = data[..., onset:onset+vol_per_clip]
        
        new_img = nib.Nifti1Image(sub_data, affine, header)
        filename = f"{subject_id}_{j+1}_{label}.nii.gz"
        save_path = os.path.join(output_dir, filename)
        new_img.to_filename(save_path)
        print(f"{subject_id}: salvato {filename}")
# Out:
# sub-01: salvato sub-01_1_calm.nii.gz
# sub-01: salvato sub-01_2_white_noise.nii.gz
# sub-01: salvato sub-01_3_afraid.nii.gz
# sub-01: salvato sub-01_4_white_noise.nii.gz
# sub-01: salvato sub-01_5_delighted.nii.gz
# sub-01: salvato sub-01_6_white_noise.nii.gz
# sub-01: salvato sub-01_7_depressed.nii.gz
# sub-01: salvato sub-01_8_white_noise.nii.gz
# sub-01: salvato sub-01_9_excited.nii.gz
# sub-01: salvato sub-01_10_white_noise.nii.gz
# sub-01: salvato sub-01_11_delighted.nii.gz
# sub-01: salvato sub-01_12_white_noise.nii.gz
# sub-01: salvato sub-01_13_depressed.nii.gz
# sub-01: salvato sub-01_14_white_noise.nii.gz
# sub-01: salvato sub-01_15_calm.nii.gz
# sub-01: salvato sub-01_16_white_noise.nii.gz
# sub-01: salvato sub-01_17_excited.nii.gz
# sub-01: salvato sub-01_18_white_noise.nii.gz
# sub-01: salvato sub-01_19_afraid.nii.gz
# sub-01: salvato sub-01_20_white_noise.nii.gz
# sub-02: salvato sub-02_1_calm.nii.gz
# sub-02: salvato sub-02_2_white_noise.nii.gz
# sub-02: salvato sub-02_3_afraid.nii.gz
# sub-02: salvato sub-02_4_white_noise.nii.gz
# sub-02: salvato sub-02_5_delighted.nii.gz
# sub-02: salvato sub-02_6_white_noise.nii.gz
# sub-02: salvato sub-02_7_depressed.nii.gz
# sub-02: salvato sub-02_8_white_noise.nii.gz
# sub-02: salvato sub-02_9_excited.nii.gz
# sub-02: salvato sub-02_10_white_noise.nii.gz
# sub-02: salvato sub-02_11_delighted.nii.gz
# sub-02: salvato sub-02_12_white_noise.nii.gz
# sub-02: salvato sub-02_13_depressed.nii.gz
# sub-02: salvato sub-02_14_white_noise.nii.gz
# sub-02: salvato sub-02_15_calm.nii.gz
# sub-02: salvato sub-02_16_white_noise.nii.gz
# sub-02: salvato sub-02_17_excited.nii.gz
# sub-02: salvato sub-02_18_white_noise.nii.gz
# sub-02: salvato sub-02_19_afraid.nii.gz
# sub-02: salvato sub-02_20_white_noise.nii.gz
# sub-03: salvato sub-03_1_calm.nii.gz
# sub-03: salvato sub-03_2_white_noise.nii.gz
# sub-03: salvato sub-03_3_afraid.nii.gz
# sub-03: salvato sub-03_4_white_noise.nii.gz
# sub-03: salvato sub-03_5_delighted.nii.gz
# sub-03: salvato sub-03_6_white_noise.nii.gz
# sub-03: salvato sub-03_7_depressed.nii.gz
# sub-03: salvato sub-03_8_white_noise.nii.gz
# sub-03: salvato sub-03_9_excited.nii.gz
# sub-03: salvato sub-03_10_white_noise.nii.gz
# sub-03: salvato sub-03_11_delighted.nii.gz
# sub-03: salvato sub-03_12_white_noise.nii.gz
# sub-03: salvato sub-03_13_depressed.nii.gz
# sub-03: salvato sub-03_14_white_noise.nii.gz
# sub-03: salvato sub-03_15_calm.nii.gz
# sub-03: salvato sub-03_16_white_noise.nii.gz
# sub-03: salvato sub-03_17_excited.nii.gz
# sub-03: salvato sub-03_18_white_noise.nii.gz
# sub-03: salvato sub-03_19_afraid.nii.gz
# sub-03: salvato sub-03_20_white_noise.nii.gz
# sub-04: salvato sub-04_1_calm.nii.gz
# sub-04: salvato sub-04_2_white_noise.nii.gz
# sub-04: salvato sub-04_3_afraid.nii.gz
# sub-04: salvato sub-04_4_white_noise.nii.gz
# sub-04: salvato sub-04_5_delighted.nii.gz
# sub-04: salvato sub-04_6_white_noise.nii.gz
# sub-04: salvato sub-04_7_depressed.nii.gz
# sub-04: salvato sub-04_8_white_noise.nii.gz
# sub-04: salvato sub-04_9_excited.nii.gz
# sub-04: salvato sub-04_10_white_noise.nii.gz
# sub-04: salvato sub-04_11_delighted.nii.gz
# sub-04: salvato sub-04_12_white_noise.nii.gz
# sub-04: salvato sub-04_13_depressed.nii.gz
# sub-04: salvato sub-04_14_white_noise.nii.gz
# sub-04: salvato sub-04_15_calm.nii.gz
# sub-04: salvato sub-04_16_white_noise.nii.gz
# sub-04: salvato sub-04_17_excited.nii.gz
# sub-04: salvato sub-04_18_white_noise.nii.gz
# sub-04: salvato sub-04_19_afraid.nii.gz
# sub-04: salvato sub-04_20_white_noise.nii.gz
# sub-05: salvato sub-05_1_calm.nii.gz
# sub-05: salvato sub-05_2_white_noise.nii.gz
# sub-05: salvato sub-05_3_afraid.nii.gz
# sub-05: salvato sub-05_4_white_noise.nii.gz
# sub-05: salvato sub-05_5_delighted.nii.gz
# sub-05: salvato sub-05_6_white_noise.nii.gz
# sub-05: salvato sub-05_7_depressed.nii.gz
# sub-05: salvato sub-05_8_white_noise.nii.gz
# sub-05: salvato sub-05_9_excited.nii.gz
# sub-05: salvato sub-05_10_white_noise.nii.gz
# sub-05: salvato sub-05_11_delighted.nii.gz
# sub-05: salvato sub-05_12_white_noise.nii.gz
# sub-05: salvato sub-05_13_depressed.nii.gz
# sub-05: salvato sub-05_14_white_noise.nii.gz
# sub-05: salvato sub-05_15_calm.nii.gz
# sub-05: salvato sub-05_16_white_noise.nii.gz
# sub-05: salvato sub-05_17_excited.nii.gz
# sub-05: salvato sub-05_18_white_noise.nii.gz
# sub-05: salvato sub-05_19_afraid.nii.gz
# sub-05: salvato sub-05_20_white_noise.nii.gz
# sub-06: salvato sub-06_1_calm.nii.gz
# sub-06: salvato sub-06_2_white_noise.nii.gz
# sub-06: salvato sub-06_3_afraid.nii.gz
# sub-06: salvato sub-06_4_white_noise.nii.gz
# sub-06: salvato sub-06_5_delighted.nii.gz
# sub-06: salvato sub-06_6_white_noise.nii.gz
# sub-06: salvato sub-06_7_depressed.nii.gz
# sub-06: salvato sub-06_8_white_noise.nii.gz
# sub-06: salvato sub-06_9_excited.nii.gz
# sub-06: salvato sub-06_10_white_noise.nii.gz
# sub-06: salvato sub-06_11_delighted.nii.gz
# sub-06: salvato sub-06_12_white_noise.nii.gz
# sub-06: salvato sub-06_13_depressed.nii.gz
# sub-06: salvato sub-06_14_white_noise.nii.gz
# sub-06: salvato sub-06_15_calm.nii.gz
# sub-06: salvato sub-06_16_white_noise.nii.gz
# sub-06: salvato sub-06_17_excited.nii.gz
# sub-06: salvato sub-06_18_white_noise.nii.gz
# sub-06: salvato sub-06_19_afraid.nii.gz
# sub-06: salvato sub-06_20_white_noise.nii.gz
# sub-07: salvato sub-07_1_calm.nii.gz
# sub-07: salvato sub-07_2_white_noise.nii.gz
# sub-07: salvato sub-07_3_afraid.nii.gz
# sub-07: salvato sub-07_4_white_noise.nii.gz
# sub-07: salvato sub-07_5_delighted.nii.gz
# sub-07: salvato sub-07_6_white_noise.nii.gz
# sub-07: salvato sub-07_7_depressed.nii.gz
# sub-07: salvato sub-07_8_white_noise.nii.gz
# sub-07: salvato sub-07_9_excited.nii.gz
# sub-07: salvato sub-07_10_white_noise.nii.gz
# sub-07: salvato sub-07_11_delighted.nii.gz
# sub-07: salvato sub-07_12_white_noise.nii.gz
# sub-07: salvato sub-07_13_depressed.nii.gz
# sub-07: salvato sub-07_14_white_noise.nii.gz
# sub-07: salvato sub-07_15_calm.nii.gz
# sub-07: salvato sub-07_16_white_noise.nii.gz
# sub-07: salvato sub-07_17_excited.nii.gz
# sub-07: salvato sub-07_18_white_noise.nii.gz
# sub-07: salvato sub-07_19_afraid.nii.gz
# sub-07: salvato sub-07_20_white_noise.nii.gz
# sub-08: salvato sub-08_1_calm.nii.gz
# sub-08: salvato sub-08_2_white_noise.nii.gz
# sub-08: salvato sub-08_3_afraid.nii.gz
# sub-08: salvato sub-08_4_white_noise.nii.gz
# sub-08: salvato sub-08_5_delighted.nii.gz
# sub-08: salvato sub-08_6_white_noise.nii.gz
# sub-08: salvato sub-08_7_depressed.nii.gz
# sub-08: salvato sub-08_8_white_noise.nii.gz
# sub-08: salvato sub-08_9_excited.nii.gz
# sub-08: salvato sub-08_10_white_noise.nii.gz
# sub-08: salvato sub-08_11_delighted.nii.gz
# sub-08: salvato sub-08_12_white_noise.nii.gz
# sub-08: salvato sub-08_13_depressed.nii.gz
# sub-08: salvato sub-08_14_white_noise.nii.gz
# sub-08: salvato sub-08_15_calm.nii.gz
# sub-08: salvato sub-08_16_white_noise.nii.gz
# sub-08: salvato sub-08_17_excited.nii.gz
# sub-08: salvato sub-08_18_white_noise.nii.gz
# sub-08: salvato sub-08_19_afraid.nii.gz
# sub-08: salvato sub-08_20_white_noise.nii.gz
# sub-09: salvato sub-09_1_calm.nii.gz
# sub-09: salvato sub-09_2_white_noise.nii.gz
# sub-09: salvato sub-09_3_afraid.nii.gz
# sub-09: salvato sub-09_4_white_noise.nii.gz
# sub-09: salvato sub-09_5_delighted.nii.gz
# sub-09: salvato sub-09_6_white_noise.nii.gz
# sub-09: salvato sub-09_7_depressed.nii.gz
# sub-09: salvato sub-09_8_white_noise.nii.gz
# sub-09: salvato sub-09_9_excited.nii.gz
# sub-09: salvato sub-09_10_white_noise.nii.gz
# sub-09: salvato sub-09_11_delighted.nii.gz
# sub-09: salvato sub-09_12_white_noise.nii.gz
# sub-09: salvato sub-09_13_depressed.nii.gz
# sub-09: salvato sub-09_14_white_noise.nii.gz
# sub-09: salvato sub-09_15_calm.nii.gz
# sub-09: salvato sub-09_16_white_noise.nii.gz
# sub-09: salvato sub-09_17_excited.nii.gz
# sub-09: salvato sub-09_18_white_noise.nii.gz
# sub-09: salvato sub-09_19_afraid.nii.gz
# sub-09: salvato sub-09_20_white_noise.nii.gz
# sub-10: salvato sub-10_1_calm.nii.gz
# sub-10: salvato sub-10_2_white_noise.nii.gz
# sub-10: salvato sub-10_3_afraid.nii.gz
# sub-10: salvato sub-10_4_white_noise.nii.gz
# sub-10: salvato sub-10_5_delighted.nii.gz
# sub-10: salvato sub-10_6_white_noise.nii.gz
# sub-10: salvato sub-10_7_depressed.nii.gz
# sub-10: salvato sub-10_8_white_noise.nii.gz
# sub-10: salvato sub-10_9_excited.nii.gz
# sub-10: salvato sub-10_10_white_noise.nii.gz
# sub-10: salvato sub-10_11_delighted.nii.gz
# sub-10: salvato sub-10_12_white_noise.nii.gz
# sub-10: salvato sub-10_13_depressed.nii.gz
# sub-10: salvato sub-10_14_white_noise.nii.gz
# sub-10: salvato sub-10_15_calm.nii.gz
# sub-10: salvato sub-10_16_white_noise.nii.gz
# sub-10: salvato sub-10_17_excited.nii.gz
# sub-10: salvato sub-10_18_white_noise.nii.gz
# sub-10: salvato sub-10_19_afraid.nii.gz
# sub-10: salvato sub-10_20_white_noise.nii.gz
# sub-11: salvato sub-11_1_calm.nii.gz
# sub-11: salvato sub-11_2_white_noise.nii.gz
# sub-11: salvato sub-11_3_afraid.nii.gz
# sub-11: salvato sub-11_4_white_noise.nii.gz
# sub-11: salvato sub-11_5_delighted.nii.gz
# sub-11: salvato sub-11_6_white_noise.nii.gz
# sub-11: salvato sub-11_7_depressed.nii.gz
# sub-11: salvato sub-11_8_white_noise.nii.gz
# sub-11: salvato sub-11_9_excited.nii.gz
# sub-11: salvato sub-11_10_white_noise.nii.gz
# sub-11: salvato sub-11_11_delighted.nii.gz
# sub-11: salvato sub-11_12_white_noise.nii.gz
# sub-11: salvato sub-11_13_depressed.nii.gz
# sub-11: salvato sub-11_14_white_noise.nii.gz
# sub-11: salvato sub-11_15_calm.nii.gz
# sub-11: salvato sub-11_16_white_noise.nii.gz
# sub-11: salvato sub-11_17_excited.nii.gz
# sub-11: salvato sub-11_18_white_noise.nii.gz
# sub-11: salvato sub-11_19_afraid.nii.gz
# sub-11: salvato sub-11_20_white_noise.nii.gz
# sub-12: salvato sub-12_1_calm.nii.gz
# sub-12: salvato sub-12_2_white_noise.nii.gz
# sub-12: salvato sub-12_3_afraid.nii.gz
# sub-12: salvato sub-12_4_white_noise.nii.gz
# sub-12: salvato sub-12_5_delighted.nii.gz
# sub-12: salvato sub-12_6_white_noise.nii.gz
# sub-12: salvato sub-12_7_depressed.nii.gz
# sub-12: salvato sub-12_8_white_noise.nii.gz
# sub-12: salvato sub-12_9_excited.nii.gz
# sub-12: salvato sub-12_10_white_noise.nii.gz
# sub-12: salvato sub-12_11_delighted.nii.gz
# sub-12: salvato sub-12_12_white_noise.nii.gz
# sub-12: salvato sub-12_13_depressed.nii.gz
# sub-12: salvato sub-12_14_white_noise.nii.gz
# sub-12: salvato sub-12_15_calm.nii.gz
# sub-12: salvato sub-12_16_white_noise.nii.gz
# sub-12: salvato sub-12_17_excited.nii.gz
# sub-12: salvato sub-12_18_white_noise.nii.gz
# sub-12: salvato sub-12_19_afraid.nii.gz
# sub-12: salvato sub-12_20_white_noise.nii.gz
# sub-13: salvato sub-13_1_calm.nii.gz
# sub-13: salvato sub-13_2_white_noise.nii.gz
# sub-13: salvato sub-13_3_afraid.nii.gz
# sub-13: salvato sub-13_4_white_noise.nii.gz
# sub-13: salvato sub-13_5_delighted.nii.gz
# sub-13: salvato sub-13_6_white_noise.nii.gz
# sub-13: salvato sub-13_7_depressed.nii.gz
# sub-13: salvato sub-13_8_white_noise.nii.gz
# sub-13: salvato sub-13_9_excited.nii.gz
# sub-13: salvato sub-13_10_white_noise.nii.gz
# sub-13: salvato sub-13_11_delighted.nii.gz
# sub-13: salvato sub-13_12_white_noise.nii.gz
# sub-13: salvato sub-13_13_depressed.nii.gz
# sub-13: salvato sub-13_14_white_noise.nii.gz
# sub-13: salvato sub-13_15_calm.nii.gz
# sub-13: salvato sub-13_16_white_noise.nii.gz
# sub-13: salvato sub-13_17_excited.nii.gz
# sub-13: salvato sub-13_18_white_noise.nii.gz
# sub-13: salvato sub-13_19_afraid.nii.gz
# sub-13: salvato sub-13_20_white_noise.nii.gz
# sub-14: salvato sub-14_1_calm.nii.gz
# sub-14: salvato sub-14_2_white_noise.nii.gz
# sub-14: salvato sub-14_3_afraid.nii.gz
# sub-14: salvato sub-14_4_white_noise.nii.gz
# sub-14: salvato sub-14_5_delighted.nii.gz
# sub-14: salvato sub-14_6_white_noise.nii.gz
# sub-14: salvato sub-14_7_depressed.nii.gz
# sub-14: salvato sub-14_8_white_noise.nii.gz
# sub-14: salvato sub-14_9_excited.nii.gz
# sub-14: salvato sub-14_10_white_noise.nii.gz
# sub-14: salvato sub-14_11_delighted.nii.gz
# sub-14: salvato sub-14_12_white_noise.nii.gz
# sub-14: salvato sub-14_13_depressed.nii.gz
# sub-14: salvato sub-14_14_white_noise.nii.gz
# sub-14: salvato sub-14_15_calm.nii.gz
# sub-14: salvato sub-14_16_white_noise.nii.gz
# sub-14: salvato sub-14_17_excited.nii.gz
# sub-14: salvato sub-14_18_white_noise.nii.gz
# sub-14: salvato sub-14_19_afraid.nii.gz
# sub-14: salvato sub-14_20_white_noise.nii.gz
# sub-15: salvato sub-15_1_calm.nii.gz
# sub-15: salvato sub-15_2_white_noise.nii.gz
# sub-15: salvato sub-15_3_afraid.nii.gz
# sub-15: salvato sub-15_4_white_noise.nii.gz
# sub-15: salvato sub-15_5_delighted.nii.gz
# sub-15: salvato sub-15_6_white_noise.nii.gz
# sub-15: salvato sub-15_7_depressed.nii.gz
# sub-15: salvato sub-15_8_white_noise.nii.gz
# sub-15: salvato sub-15_9_excited.nii.gz
# sub-15: salvato sub-15_10_white_noise.nii.gz
# sub-15: salvato sub-15_11_delighted.nii.gz
# sub-15: salvato sub-15_12_white_noise.nii.gz
# sub-15: salvato sub-15_13_depressed.nii.gz
# sub-15: salvato sub-15_14_white_noise.nii.gz
# sub-15: salvato sub-15_15_calm.nii.gz
# sub-15: salvato sub-15_16_white_noise.nii.gz
# sub-15: salvato sub-15_17_excited.nii.gz
# sub-15: salvato sub-15_18_white_noise.nii.gz
# sub-15: salvato sub-15_19_afraid.nii.gz
# sub-15: salvato sub-15_20_white_noise.nii.gz
# sub-16: salvato sub-16_1_calm.nii.gz
# sub-16: salvato sub-16_2_white_noise.nii.gz
# sub-16: salvato sub-16_3_afraid.nii.gz
# sub-16: salvato sub-16_4_white_noise.nii.gz
# sub-16: salvato sub-16_5_delighted.nii.gz
# sub-16: salvato sub-16_6_white_noise.nii.gz
# sub-16: salvato sub-16_7_depressed.nii.gz
# sub-16: salvato sub-16_8_white_noise.nii.gz
# sub-16: salvato sub-16_9_excited.nii.gz
# sub-16: salvato sub-16_10_white_noise.nii.gz
# sub-16: salvato sub-16_11_delighted.nii.gz
# sub-16: salvato sub-16_12_white_noise.nii.gz
# sub-16: salvato sub-16_13_depressed.nii.gz
# sub-16: salvato sub-16_14_white_noise.nii.gz
# sub-16: salvato sub-16_15_calm.nii.gz
# sub-16: salvato sub-16_16_white_noise.nii.gz
# sub-16: salvato sub-16_17_excited.nii.gz
# sub-16: salvato sub-16_18_white_noise.nii.gz
# sub-16: salvato sub-16_19_afraid.nii.gz
# sub-16: salvato sub-16_20_white_noise.nii.gz
# sub-17: salvato sub-17_1_calm.nii.gz
# sub-17: salvato sub-17_2_white_noise.nii.gz
# sub-17: salvato sub-17_3_afraid.nii.gz
# sub-17: salvato sub-17_4_white_noise.nii.gz
# sub-17: salvato sub-17_5_delighted.nii.gz
# sub-17: salvato sub-17_6_white_noise.nii.gz
# sub-17: salvato sub-17_7_depressed.nii.gz
# sub-17: salvato sub-17_8_white_noise.nii.gz
# sub-17: salvato sub-17_9_excited.nii.gz
# sub-17: salvato sub-17_10_white_noise.nii.gz
# sub-17: salvato sub-17_11_delighted.nii.gz
# sub-17: salvato sub-17_12_white_noise.nii.gz
# sub-17: salvato sub-17_13_depressed.nii.gz
# sub-17: salvato sub-17_14_white_noise.nii.gz
# sub-17: salvato sub-17_15_calm.nii.gz
# sub-17: salvato sub-17_16_white_noise.nii.gz
# sub-17: salvato sub-17_17_excited.nii.gz
# sub-17: salvato sub-17_18_white_noise.nii.gz
# sub-17: salvato sub-17_19_afraid.nii.gz
# sub-17: salvato sub-17_20_white_noise.nii.gz
# sub-18: salvato sub-18_1_calm.nii.gz
# sub-18: salvato sub-18_2_white_noise.nii.gz
# sub-18: salvato sub-18_3_afraid.nii.gz
# sub-18: salvato sub-18_4_white_noise.nii.gz
# sub-18: salvato sub-18_5_delighted.nii.gz
# sub-18: salvato sub-18_6_white_noise.nii.gz
# sub-18: salvato sub-18_7_depressed.nii.gz
# sub-18: salvato sub-18_8_white_noise.nii.gz
# sub-18: salvato sub-18_9_excited.nii.gz
# sub-18: salvato sub-18_10_white_noise.nii.gz
# sub-18: salvato sub-18_11_delighted.nii.gz
# sub-18: salvato sub-18_12_white_noise.nii.gz
# sub-18: salvato sub-18_13_depressed.nii.gz
# sub-18: salvato sub-18_14_white_noise.nii.gz
# sub-18: salvato sub-18_15_calm.nii.gz
# sub-18: salvato sub-18_16_white_noise.nii.gz
# sub-18: salvato sub-18_17_excited.nii.gz
# sub-18: salvato sub-18_18_white_noise.nii.gz
# sub-18: salvato sub-18_19_afraid.nii.gz
# sub-18: salvato sub-18_20_white_noise.nii.gz
# sub-19: salvato sub-19_1_calm.nii.gz
# sub-19: salvato sub-19_2_white_noise.nii.gz
# sub-19: salvato sub-19_3_afraid.nii.gz
# sub-19: salvato sub-19_4_white_noise.nii.gz
# sub-19: salvato sub-19_5_delighted.nii.gz
# sub-19: salvato sub-19_6_white_noise.nii.gz
# sub-19: salvato sub-19_7_depressed.nii.gz
# sub-19: salvato sub-19_8_white_noise.nii.gz
# sub-19: salvato sub-19_9_excited.nii.gz
# sub-19: salvato sub-19_10_white_noise.nii.gz
# sub-19: salvato sub-19_11_delighted.nii.gz
# sub-19: salvato sub-19_12_white_noise.nii.gz
# sub-19: salvato sub-19_13_depressed.nii.gz
# sub-19: salvato sub-19_14_white_noise.nii.gz
# sub-19: salvato sub-19_15_calm.nii.gz
# sub-19: salvato sub-19_16_white_noise.nii.gz
# sub-19: salvato sub-19_17_excited.nii.gz
# sub-19: salvato sub-19_18_white_noise.nii.gz
# sub-19: salvato sub-19_19_afraid.nii.gz
# sub-19: salvato sub-19_20_white_noise.nii.gz
# sub-20: salvato sub-20_1_calm.nii.gz
# sub-20: salvato sub-20_2_white_noise.nii.gz
# sub-20: salvato sub-20_3_afraid.nii.gz
# sub-20: salvato sub-20_4_white_noise.nii.gz
# sub-20: salvato sub-20_5_delighted.nii.gz
# sub-20: salvato sub-20_6_white_noise.nii.gz
# sub-20: salvato sub-20_7_depressed.nii.gz
# sub-20: salvato sub-20_8_white_noise.nii.gz
# sub-20: salvato sub-20_9_excited.nii.gz
# sub-20: salvato sub-20_10_white_noise.nii.gz
# sub-20: salvato sub-20_11_delighted.nii.gz
# sub-20: salvato sub-20_12_white_noise.nii.gz
# sub-20: salvato sub-20_13_depressed.nii.gz
# sub-20: salvato sub-20_14_white_noise.nii.gz
# sub-20: salvato sub-20_15_calm.nii.gz
# sub-20: salvato sub-20_16_white_noise.nii.gz
# sub-20: salvato sub-20_17_excited.nii.gz
# sub-20: salvato sub-20_18_white_noise.nii.gz
# sub-20: salvato sub-20_19_afraid.nii.gz
# sub-20: salvato sub-20_20_white_noise.nii.gz
# sub-21: salvato sub-21_1_calm.nii.gz
# sub-21: salvato sub-21_2_white_noise.nii.gz
# sub-21: salvato sub-21_3_afraid.nii.gz
# sub-21: salvato sub-21_4_white_noise.nii.gz
# sub-21: salvato sub-21_5_delighted.nii.gz
# sub-21: salvato sub-21_6_white_noise.nii.gz
# sub-21: salvato sub-21_7_depressed.nii.gz
# sub-21: salvato sub-21_8_white_noise.nii.gz
# sub-21: salvato sub-21_9_excited.nii.gz
# sub-21: salvato sub-21_10_white_noise.nii.gz
# sub-21: salvato sub-21_11_delighted.nii.gz
# sub-21: salvato sub-21_12_white_noise.nii.gz
# sub-21: salvato sub-21_13_depressed.nii.gz
# sub-21: salvato sub-21_14_white_noise.nii.gz
# sub-21: salvato sub-21_15_calm.nii.gz
# sub-21: salvato sub-21_16_white_noise.nii.gz
# sub-21: salvato sub-21_17_excited.nii.gz
# sub-21: salvato sub-21_18_white_noise.nii.gz
# sub-21: salvato sub-21_19_afraid.nii.gz
# sub-21: salvato sub-21_20_white_noise.nii.gz
# sub-22: salvato sub-22_1_calm.nii.gz
# sub-22: salvato sub-22_2_white_noise.nii.gz
# sub-22: salvato sub-22_3_afraid.nii.gz
# sub-22: salvato sub-22_4_white_noise.nii.gz
# sub-22: salvato sub-22_5_delighted.nii.gz
# sub-22: salvato sub-22_6_white_noise.nii.gz
# sub-22: salvato sub-22_7_depressed.nii.gz
# sub-22: salvato sub-22_8_white_noise.nii.gz
# sub-22: salvato sub-22_9_excited.nii.gz
# sub-22: salvato sub-22_10_white_noise.nii.gz
# sub-22: salvato sub-22_11_delighted.nii.gz
# sub-22: salvato sub-22_12_white_noise.nii.gz
# sub-22: salvato sub-22_13_depressed.nii.gz
# sub-22: salvato sub-22_14_white_noise.nii.gz
# sub-22: salvato sub-22_15_calm.nii.gz
# sub-22: salvato sub-22_16_white_noise.nii.gz
# sub-22: salvato sub-22_17_excited.nii.gz
# sub-22: salvato sub-22_18_white_noise.nii.gz
# sub-22: salvato sub-22_19_afraid.nii.gz
# sub-22: salvato sub-22_20_white_noise.nii.gz
# sub-23: salvato sub-23_1_calm.nii.gz
# sub-23: salvato sub-23_2_white_noise.nii.gz
# sub-23: salvato sub-23_3_afraid.nii.gz
# sub-23: salvato sub-23_4_white_noise.nii.gz
# sub-23: salvato sub-23_5_delighted.nii.gz
# sub-23: salvato sub-23_6_white_noise.nii.gz
# sub-23: salvato sub-23_7_depressed.nii.gz
# sub-23: salvato sub-23_8_white_noise.nii.gz
# sub-23: salvato sub-23_9_excited.nii.gz
# sub-23: salvato sub-23_10_white_noise.nii.gz
# sub-23: salvato sub-23_11_delighted.nii.gz
# sub-23: salvato sub-23_12_white_noise.nii.gz
# sub-23: salvato sub-23_13_depressed.nii.gz
# sub-23: salvato sub-23_14_white_noise.nii.gz
# sub-23: salvato sub-23_15_calm.nii.gz
# sub-23: salvato sub-23_16_white_noise.nii.gz
# sub-23: salvato sub-23_17_excited.nii.gz
# sub-23: salvato sub-23_18_white_noise.nii.gz
# sub-23: salvato sub-23_19_afraid.nii.gz
# sub-23: salvato sub-23_20_white_noise.nii.gz
# sub-24: salvato sub-24_1_calm.nii.gz
# sub-24: salvato sub-24_2_white_noise.nii.gz
# sub-24: salvato sub-24_3_afraid.nii.gz
# sub-24: salvato sub-24_4_white_noise.nii.gz
# sub-24: salvato sub-24_5_delighted.nii.gz
# sub-24: salvato sub-24_6_white_noise.nii.gz
# sub-24: salvato sub-24_7_depressed.nii.gz
# sub-24: salvato sub-24_8_white_noise.nii.gz
# sub-24: salvato sub-24_9_excited.nii.gz
# sub-24: salvato sub-24_10_white_noise.nii.gz
# sub-24: salvato sub-24_11_delighted.nii.gz
# sub-24: salvato sub-24_12_white_noise.nii.gz
# sub-24: salvato sub-24_13_depressed.nii.gz
# sub-24: salvato sub-24_14_white_noise.nii.gz
# sub-24: salvato sub-24_15_calm.nii.gz
# sub-24: salvato sub-24_16_white_noise.nii.gz
# sub-24: salvato sub-24_17_excited.nii.gz
# sub-24: salvato sub-24_18_white_noise.nii.gz
# sub-24: salvato sub-24_19_afraid.nii.gz
# sub-24: salvato sub-24_20_white_noise.nii.gz
# sub-25: salvato sub-25_1_calm.nii.gz
# sub-25: salvato sub-25_2_white_noise.nii.gz
# sub-25: salvato sub-25_3_afraid.nii.gz
# sub-25: salvato sub-25_4_white_noise.nii.gz
# sub-25: salvato sub-25_5_delighted.nii.gz
# sub-25: salvato sub-25_6_white_noise.nii.gz
# sub-25: salvato sub-25_7_depressed.nii.gz
# sub-25: salvato sub-25_8_white_noise.nii.gz
# sub-25: salvato sub-25_9_excited.nii.gz
# sub-25: salvato sub-25_10_white_noise.nii.gz
# sub-25: salvato sub-25_11_delighted.nii.gz
# sub-25: salvato sub-25_12_white_noise.nii.gz
# sub-25: salvato sub-25_13_depressed.nii.gz
# sub-25: salvato sub-25_14_white_noise.nii.gz
# sub-25: salvato sub-25_15_calm.nii.gz
# sub-25: salvato sub-25_16_white_noise.nii.gz
# sub-25: salvato sub-25_17_excited.nii.gz
# sub-25: salvato sub-25_18_white_noise.nii.gz
# sub-25: salvato sub-25_19_afraid.nii.gz
# sub-25: salvato sub-25_20_white_noise.nii.gz
# sub-26: salvato sub-26_1_calm.nii.gz
# sub-26: salvato sub-26_2_white_noise.nii.gz
# sub-26: salvato sub-26_3_afraid.nii.gz
# sub-26: salvato sub-26_4_white_noise.nii.gz
# sub-26: salvato sub-26_5_delighted.nii.gz
# sub-26: salvato sub-26_6_white_noise.nii.gz
# sub-26: salvato sub-26_7_depressed.nii.gz
# sub-26: salvato sub-26_8_white_noise.nii.gz
# sub-26: salvato sub-26_9_excited.nii.gz
# sub-26: salvato sub-26_10_white_noise.nii.gz
# sub-26: salvato sub-26_11_delighted.nii.gz
# sub-26: salvato sub-26_12_white_noise.nii.gz
# sub-26: salvato sub-26_13_depressed.nii.gz
# sub-26: salvato sub-26_14_white_noise.nii.gz
# sub-26: salvato sub-26_15_calm.nii.gz
# sub-26: salvato sub-26_16_white_noise.nii.gz
# sub-26: salvato sub-26_17_excited.nii.gz
# sub-26: salvato sub-26_18_white_noise.nii.gz
# sub-26: salvato sub-26_19_afraid.nii.gz
# sub-26: salvato sub-26_20_white_noise.nii.gz
# sub-27: salvato sub-27_1_calm.nii.gz
# sub-27: salvato sub-27_2_white_noise.nii.gz
# sub-27: salvato sub-27_3_afraid.nii.gz
# sub-27: salvato sub-27_4_white_noise.nii.gz
# sub-27: salvato sub-27_5_delighted.nii.gz
# sub-27: salvato sub-27_6_white_noise.nii.gz
# sub-27: salvato sub-27_7_depressed.nii.gz
# sub-27: salvato sub-27_8_white_noise.nii.gz
# sub-27: salvato sub-27_9_excited.nii.gz
# sub-27: salvato sub-27_10_white_noise.nii.gz
# sub-27: salvato sub-27_11_delighted.nii.gz
# sub-27: salvato sub-27_12_white_noise.nii.gz
# sub-27: salvato sub-27_13_depressed.nii.gz
# sub-27: salvato sub-27_14_white_noise.nii.gz
# sub-27: salvato sub-27_15_calm.nii.gz
# sub-27: salvato sub-27_16_white_noise.nii.gz
# sub-27: salvato sub-27_17_excited.nii.gz
# sub-27: salvato sub-27_18_white_noise.nii.gz
# sub-27: salvato sub-27_19_afraid.nii.gz
# sub-27: salvato sub-27_20_white_noise.nii.gz
# sub-28: salvato sub-28_1_calm.nii.gz
# sub-28: salvato sub-28_2_white_noise.nii.gz
# sub-28: salvato sub-28_3_afraid.nii.gz
# sub-28: salvato sub-28_4_white_noise.nii.gz
# sub-28: salvato sub-28_5_delighted.nii.gz
# sub-28: salvato sub-28_6_white_noise.nii.gz
# sub-28: salvato sub-28_7_depressed.nii.gz
# sub-28: salvato sub-28_8_white_noise.nii.gz
# sub-28: salvato sub-28_9_excited.nii.gz
# sub-28: salvato sub-28_10_white_noise.nii.gz
# sub-28: salvato sub-28_11_delighted.nii.gz
# sub-28: salvato sub-28_12_white_noise.nii.gz
# sub-28: salvato sub-28_13_depressed.nii.gz
# sub-28: salvato sub-28_14_white_noise.nii.gz
# sub-28: salvato sub-28_15_calm.nii.gz
# sub-28: salvato sub-28_16_white_noise.nii.gz
# sub-28: salvato sub-28_17_excited.nii.gz
# sub-28: salvato sub-28_18_white_noise.nii.gz
# sub-28: salvato sub-28_19_afraid.nii.gz
# sub-28: salvato sub-28_20_white_noise.nii.gz
# sub-29: salvato sub-29_1_calm.nii.gz
# sub-29: salvato sub-29_2_white_noise.nii.gz
# sub-29: salvato sub-29_3_afraid.nii.gz
# sub-29: salvato sub-29_4_white_noise.nii.gz
# sub-29: salvato sub-29_5_delighted.nii.gz
# sub-29: salvato sub-29_6_white_noise.nii.gz
# sub-29: salvato sub-29_7_depressed.nii.gz
# sub-29: salvato sub-29_8_white_noise.nii.gz
# sub-29: salvato sub-29_9_excited.nii.gz
# sub-29: salvato sub-29_10_white_noise.nii.gz
# sub-29: salvato sub-29_11_delighted.nii.gz
# sub-29: salvato sub-29_12_white_noise.nii.gz
# sub-29: salvato sub-29_13_depressed.nii.gz
# sub-29: salvato sub-29_14_white_noise.nii.gz
# sub-29: salvato sub-29_15_calm.nii.gz
# sub-29: salvato sub-29_16_white_noise.nii.gz
# sub-29: salvato sub-29_17_excited.nii.gz
# sub-29: salvato sub-29_18_white_noise.nii.gz
# sub-29: salvato sub-29_19_afraid.nii.gz
# sub-29: salvato sub-29_20_white_noise.nii.gz
# sub-30: salvato sub-30_1_calm.nii.gz
# sub-30: salvato sub-30_2_white_noise.nii.gz
# sub-30: salvato sub-30_3_afraid.nii.gz
# sub-30: salvato sub-30_4_white_noise.nii.gz
# sub-30: salvato sub-30_5_delighted.nii.gz
# sub-30: salvato sub-30_6_white_noise.nii.gz
# sub-30: salvato sub-30_7_depressed.nii.gz
# sub-30: salvato sub-30_8_white_noise.nii.gz
# sub-30: salvato sub-30_9_excited.nii.gz
# sub-30: salvato sub-30_10_white_noise.nii.gz
# sub-30: salvato sub-30_11_delighted.nii.gz
# sub-30: salvato sub-30_12_white_noise.nii.gz
# sub-30: salvato sub-30_13_depressed.nii.gz
# sub-30: salvato sub-30_14_white_noise.nii.gz
# sub-30: salvato sub-30_15_calm.nii.gz
# sub-30: salvato sub-30_16_white_noise.nii.gz
# sub-30: salvato sub-30_17_excited.nii.gz
# sub-30: salvato sub-30_18_white_noise.nii.gz
# sub-30: salvato sub-30_19_afraid.nii.gz
# sub-30: salvato sub-30_20_white_noise.nii.gz
# sub-31: salvato sub-31_1_calm.nii.gz
# sub-31: salvato sub-31_2_white_noise.nii.gz
# sub-31: salvato sub-31_3_afraid.nii.gz
# sub-31: salvato sub-31_4_white_noise.nii.gz
# sub-31: salvato sub-31_5_delighted.nii.gz
# sub-31: salvato sub-31_6_white_noise.nii.gz
# sub-31: salvato sub-31_7_depressed.nii.gz
# sub-31: salvato sub-31_8_white_noise.nii.gz
# sub-31: salvato sub-31_9_excited.nii.gz
# sub-31: salvato sub-31_10_white_noise.nii.gz
# sub-31: salvato sub-31_11_delighted.nii.gz
# sub-31: salvato sub-31_12_white_noise.nii.gz
# sub-31: salvato sub-31_13_depressed.nii.gz
# sub-31: salvato sub-31_14_white_noise.nii.gz
# sub-31: salvato sub-31_15_calm.nii.gz
# sub-31: salvato sub-31_16_white_noise.nii.gz
# sub-31: salvato sub-31_17_excited.nii.gz
# sub-31: salvato sub-31_18_white_noise.nii.gz
# sub-31: salvato sub-31_19_afraid.nii.gz
# sub-31: salvato sub-31_20_white_noise.nii.gz
# sub-32: salvato sub-32_1_calm.nii.gz
# sub-32: salvato sub-32_2_white_noise.nii.gz
# sub-32: salvato sub-32_3_afraid.nii.gz
# sub-32: salvato sub-32_4_white_noise.nii.gz
# sub-32: salvato sub-32_5_delighted.nii.gz
# sub-32: salvato sub-32_6_white_noise.nii.gz
# sub-32: salvato sub-32_7_depressed.nii.gz
# sub-32: salvato sub-32_8_white_noise.nii.gz
# sub-32: salvato sub-32_9_excited.nii.gz
# sub-32: salvato sub-32_10_white_noise.nii.gz
# sub-32: salvato sub-32_11_delighted.nii.gz
# sub-32: salvato sub-32_12_white_noise.nii.gz
# sub-32: salvato sub-32_13_depressed.nii.gz
# sub-32: salvato sub-32_14_white_noise.nii.gz
# sub-32: salvato sub-32_15_calm.nii.gz
# sub-32: salvato sub-32_16_white_noise.nii.gz
# sub-32: salvato sub-32_17_excited.nii.gz
# sub-32: salvato sub-32_18_white_noise.nii.gz
# sub-32: salvato sub-32_19_afraid.nii.gz
# sub-32: salvato sub-32_20_white_noise.nii.gz
# sub-33: salvato sub-33_1_calm.nii.gz
# sub-33: salvato sub-33_2_white_noise.nii.gz
# sub-33: salvato sub-33_3_afraid.nii.gz
# sub-33: salvato sub-33_4_white_noise.nii.gz
# sub-33: salvato sub-33_5_delighted.nii.gz
# sub-33: salvato sub-33_6_white_noise.nii.gz
# sub-33: salvato sub-33_7_depressed.nii.gz
# sub-33: salvato sub-33_8_white_noise.nii.gz
# sub-33: salvato sub-33_9_excited.nii.gz
# sub-33: salvato sub-33_10_white_noise.nii.gz
# sub-33: salvato sub-33_11_delighted.nii.gz
# sub-33: salvato sub-33_12_white_noise.nii.gz
# sub-33: salvato sub-33_13_depressed.nii.gz
# sub-33: salvato sub-33_14_white_noise.nii.gz
# sub-33: salvato sub-33_15_calm.nii.gz
# sub-33: salvato sub-33_16_white_noise.nii.gz
# sub-33: salvato sub-33_17_excited.nii.gz
# sub-33: salvato sub-33_18_white_noise.nii.gz
# sub-33: salvato sub-33_19_afraid.nii.gz
# sub-33: salvato sub-33_20_white_noise.nii.gz
# sub-34: salvato sub-34_1_calm.nii.gz
# sub-34: salvato sub-34_2_white_noise.nii.gz
# sub-34: salvato sub-34_3_afraid.nii.gz
# sub-34: salvato sub-34_4_white_noise.nii.gz
# sub-34: salvato sub-34_5_delighted.nii.gz
# sub-34: salvato sub-34_6_white_noise.nii.gz
# sub-34: salvato sub-34_7_depressed.nii.gz
# sub-34: salvato sub-34_8_white_noise.nii.gz
# sub-34: salvato sub-34_9_excited.nii.gz
# sub-34: salvato sub-34_10_white_noise.nii.gz
# sub-34: salvato sub-34_11_delighted.nii.gz
# sub-34: salvato sub-34_12_white_noise.nii.gz
# sub-34: salvato sub-34_13_depressed.nii.gz
# sub-34: salvato sub-34_14_white_noise.nii.gz
# sub-34: salvato sub-34_15_calm.nii.gz
# sub-34: salvato sub-34_16_white_noise.nii.gz
# sub-34: salvato sub-34_17_excited.nii.gz
# sub-34: salvato sub-34_18_white_noise.nii.gz
# sub-34: salvato sub-34_19_afraid.nii.gz
# sub-34: salvato sub-34_20_white_noise.nii.gz
# sub-35: salvato sub-35_1_calm.nii.gz
# sub-35: salvato sub-35_2_white_noise.nii.gz
# sub-35: salvato sub-35_3_afraid.nii.gz
# sub-35: salvato sub-35_4_white_noise.nii.gz
# sub-35: salvato sub-35_5_delighted.nii.gz
# sub-35: salvato sub-35_6_white_noise.nii.gz
# sub-35: salvato sub-35_7_depressed.nii.gz
# sub-35: salvato sub-35_8_white_noise.nii.gz
# sub-35: salvato sub-35_9_excited.nii.gz
# sub-35: salvato sub-35_10_white_noise.nii.gz
# sub-35: salvato sub-35_11_delighted.nii.gz
# sub-35: salvato sub-35_12_white_noise.nii.gz
# sub-35: salvato sub-35_13_depressed.nii.gz
# sub-35: salvato sub-35_14_white_noise.nii.gz
# sub-35: salvato sub-35_15_calm.nii.gz
# sub-35: salvato sub-35_16_white_noise.nii.gz
# sub-35: salvato sub-35_17_excited.nii.gz
# sub-35: salvato sub-35_18_white_noise.nii.gz
# sub-35: salvato sub-35_19_afraid.nii.gz
# sub-35: salvato sub-35_20_white_noise.nii.gz
# sub-36: salvato sub-36_1_calm.nii.gz
# sub-36: salvato sub-36_2_white_noise.nii.gz
# sub-36: salvato sub-36_3_afraid.nii.gz
# sub-36: salvato sub-36_4_white_noise.nii.gz
# sub-36: salvato sub-36_5_delighted.nii.gz
# sub-36: salvato sub-36_6_white_noise.nii.gz
# sub-36: salvato sub-36_7_depressed.nii.gz
# sub-36: salvato sub-36_8_white_noise.nii.gz
# sub-36: salvato sub-36_9_excited.nii.gz
# sub-36: salvato sub-36_10_white_noise.nii.gz
# sub-36: salvato sub-36_11_delighted.nii.gz
# sub-36: salvato sub-36_12_white_noise.nii.gz
# sub-36: salvato sub-36_13_depressed.nii.gz
# sub-36: salvato sub-36_14_white_noise.nii.gz
# sub-36: salvato sub-36_15_calm.nii.gz
# sub-36: salvato sub-36_16_white_noise.nii.gz
# sub-36: salvato sub-36_17_excited.nii.gz
# sub-36: salvato sub-36_18_white_noise.nii.gz
# sub-36: salvato sub-36_19_afraid.nii.gz
# sub-36: salvato sub-36_20_white_noise.nii.gz
# sub-37: salvato sub-37_1_calm.nii.gz
# sub-37: salvato sub-37_2_white_noise.nii.gz
# sub-37: salvato sub-37_3_afraid.nii.gz
# sub-37: salvato sub-37_4_white_noise.nii.gz
# sub-37: salvato sub-37_5_delighted.nii.gz
# sub-37: salvato sub-37_6_white_noise.nii.gz
# sub-37: salvato sub-37_7_depressed.nii.gz
# sub-37: salvato sub-37_8_white_noise.nii.gz
# sub-37: salvato sub-37_9_excited.nii.gz
# sub-37: salvato sub-37_10_white_noise.nii.gz
# sub-37: salvato sub-37_11_delighted.nii.gz
# sub-37: salvato sub-37_12_white_noise.nii.gz
# sub-37: salvato sub-37_13_depressed.nii.gz
# sub-37: salvato sub-37_14_white_noise.nii.gz
# sub-37: salvato sub-37_15_calm.nii.gz
# sub-37: salvato sub-37_16_white_noise.nii.gz
# sub-37: salvato sub-37_17_excited.nii.gz
# sub-37: salvato sub-37_18_white_noise.nii.gz
# sub-37: salvato sub-37_19_afraid.nii.gz
# sub-37: salvato sub-37_20_white_noise.nii.gz
# sub-38: salvato sub-38_1_calm.nii.gz
# sub-38: salvato sub-38_2_white_noise.nii.gz
# sub-38: salvato sub-38_3_afraid.nii.gz
# sub-38: salvato sub-38_4_white_noise.nii.gz
# sub-38: salvato sub-38_5_delighted.nii.gz
# sub-38: salvato sub-38_6_white_noise.nii.gz
# sub-38: salvato sub-38_7_depressed.nii.gz
# sub-38: salvato sub-38_8_white_noise.nii.gz
# sub-38: salvato sub-38_9_excited.nii.gz
# sub-38: salvato sub-38_10_white_noise.nii.gz
# sub-38: salvato sub-38_11_delighted.nii.gz
# sub-38: salvato sub-38_12_white_noise.nii.gz
# sub-38: salvato sub-38_13_depressed.nii.gz
# sub-38: salvato sub-38_14_white_noise.nii.gz
# sub-38: salvato sub-38_15_calm.nii.gz
# sub-38: salvato sub-38_16_white_noise.nii.gz
# sub-38: salvato sub-38_17_excited.nii.gz
# sub-38: salvato sub-38_18_white_noise.nii.gz
# sub-38: salvato sub-38_19_afraid.nii.gz
# sub-38: salvato sub-38_20_white_noise.nii.gz
# sub-39: salvato sub-39_1_calm.nii.gz
# sub-39: salvato sub-39_2_white_noise.nii.gz
# sub-39: salvato sub-39_3_afraid.nii.gz
# sub-39: salvato sub-39_4_white_noise.nii.gz
# sub-39: salvato sub-39_5_delighted.nii.gz
# sub-39: salvato sub-39_6_white_noise.nii.gz
# sub-39: salvato sub-39_7_depressed.nii.gz
# sub-39: salvato sub-39_8_white_noise.nii.gz
# sub-39: salvato sub-39_9_excited.nii.gz
# sub-39: salvato sub-39_10_white_noise.nii.gz
# sub-39: salvato sub-39_11_delighted.nii.gz
# sub-39: salvato sub-39_12_white_noise.nii.gz
# sub-39: salvato sub-39_13_depressed.nii.gz
# sub-39: salvato sub-39_14_white_noise.nii.gz
# sub-39: salvato sub-39_15_calm.nii.gz
# sub-39: salvato sub-39_16_white_noise.nii.gz
# sub-39: salvato sub-39_17_excited.nii.gz
# sub-39: salvato sub-39_18_white_noise.nii.gz
# sub-39: salvato sub-39_19_afraid.nii.gz
# sub-39: salvato sub-39_20_white_noise.nii.gz
# sub-40: salvato sub-40_1_calm.nii.gz
# sub-40: salvato sub-40_2_white_noise.nii.gz
# sub-40: salvato sub-40_3_afraid.nii.gz
# sub-40: salvato sub-40_4_white_noise.nii.gz
# sub-40: salvato sub-40_5_delighted.nii.gz
# sub-40: salvato sub-40_6_white_noise.nii.gz
# sub-40: salvato sub-40_7_depressed.nii.gz
# sub-40: salvato sub-40_8_white_noise.nii.gz
# sub-40: salvato sub-40_9_excited.nii.gz
# sub-40: salvato sub-40_10_white_noise.nii.gz
# sub-40: salvato sub-40_11_delighted.nii.gz
# sub-40: salvato sub-40_12_white_noise.nii.gz
# sub-40: salvato sub-40_13_depressed.nii.gz
# sub-40: salvato sub-40_14_white_noise.nii.gz
# sub-40: salvato sub-40_15_calm.nii.gz
# sub-40: salvato sub-40_16_white_noise.nii.gz
# sub-40: salvato sub-40_17_excited.nii.gz
# sub-40: salvato sub-40_18_white_noise.nii.gz
# sub-40: salvato sub-40_19_afraid.nii.gz
# sub-40: salvato sub-40_20_white_noise.nii.gz

# %% [markdown]
# ## concatenate emotions for each subject

# %%
from nilearn.image import concat_imgs

base_path = "/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA"

for i in range(1, 41):
    subj_id = f"sub-{i:02d}"
    path_1 = os.path.join(base_path, subj_id, "func", f"{subj_id}_splitted", f"{subj_id}_1_calm.nii.gz")
    path_15 = os.path.join(base_path, subj_id, "func", f"{subj_id}_splitted", f"{subj_id}_15_calm.nii.gz")

    concat_img = concat_imgs([path_1, path_15])

    output_dir = os.path.join(base_path, subj_id, "func", f"concatenate_emotions_{subj_id}")
    os.makedirs(output_dir, exist_ok=True)

    output_path = os.path.join(output_dir, f"calm_{subj_id}.nii.gz")
    concat_img.to_filename(output_path)

# %%
# Loop over all subjects (from 01 to 40)
for sub_id in range(1, 41):  # from 1 to 40 inclusive
    sub_str = f"{sub_id:02d}"  # Ensure the ID is in the format "01", "02", ..., "40"
    
    # Paths of the files to concatenate (for the specific subject)
    file_paths = [
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_9_excited.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_17_excited.nii.gz"
    ]
    
    # Load all NIfTI files
    imgs = [nib.load(f) for f in file_paths]
    
    # Extract data and concatenate along the time axis (last axis)
    data_concat = np.concatenate([img.get_fdata() for img in imgs], axis=3)
    
    # Use the affine and header from the first file as reference
    affine = imgs[0].affine
    header = imgs[0].header
    
    # Create the concatenated image
    concat_img = nib.Nifti1Image(data_concat, affine=affine, header=header)
    
    # Output directory
    output_dir = f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/concatenated_emotions_sub-{sub_str}"
    os.makedirs(output_dir, exist_ok=True)
    
    output_path = os.path.join(output_dir, f"sub-{sub_str}_excited.nii.gz")
    
    # Save the file
    nib.save(concat_img, output_path)
    
    print(f"File salvato in: {output_path}")
# Out:
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-01/func/concatenated_emotions_sub-01/sub-01_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-02/func/concatenated_emotions_sub-02/sub-02_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-03/func/concatenated_emotions_sub-03/sub-03_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-04/func/concatenated_emotions_sub-04/sub-04_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-05/func/concatenated_emotions_sub-05/sub-05_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-06/func/concatenated_emotions_sub-06/sub-06_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-07/func/concatenated_emotions_sub-07/sub-07_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-08/func/concatenated_emotions_sub-08/sub-08_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-09/func/concatenated_emotions_sub-09/sub-09_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-10/func/concatenated_emotions_sub-10/sub-10_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-11/func/concatenated_emotions_sub-11/sub-11_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-12/func/concatenated_emotions_sub-12/sub-12_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-13/func/concatenated_emotions_sub-13/sub-13_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-14/func/concatenated_emotions_sub-14/sub-14_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-15/func/concatenated_emotions_sub-15/sub-15_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-16/func/concatenated_emotions_sub-16/sub-16_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-17/func/concatenated_emotions_sub-17/sub-17_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-18/func/concatenated_emotions_sub-18/sub-18_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-19/func/concatenated_emotions_sub-19/sub-19_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-20/func/concatenated_emotions_sub-20/sub-20_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-21/func/concatenated_emotions_sub-21/sub-21_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-22/func/concatenated_emotions_sub-22/sub-22_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-23/func/concatenated_emotions_sub-23/sub-23_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-24/func/concatenated_emotions_sub-24/sub-24_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-25/func/concatenated_emotions_sub-25/sub-25_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-26/func/concatenated_emotions_sub-26/sub-26_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-27/func/concatenated_emotions_sub-27/sub-27_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-28/func/concatenated_emotions_sub-28/sub-28_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-29/func/concatenated_emotions_sub-29/sub-29_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-30/func/concatenated_emotions_sub-30/sub-30_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-31/func/concatenated_emotions_sub-31/sub-31_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-32/func/concatenated_emotions_sub-32/sub-32_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-33/func/concatenated_emotions_sub-33/sub-33_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-34/func/concatenated_emotions_sub-34/sub-34_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-35/func/concatenated_emotions_sub-35/sub-35_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-36/func/concatenated_emotions_sub-36/sub-36_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-37/func/concatenated_emotions_sub-37/sub-37_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-38/func/concatenated_emotions_sub-38/sub-38_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-39/func/concatenated_emotions_sub-39/sub-39_excited.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-40/func/concatenated_emotions_sub-40/sub-40_excited.nii.gz

# %% [markdown]
# ## concatene all the emotions together and all the white noise together

# %%
# Loop through all subjects (from 01 to 40)
for sub_id in range(1, 41):  # from 1 to 40 inclusive
    sub_str = f"{sub_id:02d}"  # Ensure the ID is in the format "01", "02", ..., "40"
    
    # Paths of the files to concatenate (for the specific subject)
    file_paths = [
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_1_calm.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_3_afraid.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_5_delighted.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_7_depressed.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_9_excited.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_11_delighted.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_13_depressed.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_15_calm.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_17_excited.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_19_afraid.nii.gz",
    ]
    
    # Load all NIfTI files
    imgs = [nib.load(f) for f in file_paths]
    
    # Extract data and concatenate along the time axis (last axis)
    data_concat = np.concatenate([img.get_fdata() for img in imgs], axis=3)
    
    # Use the affine and header from the first file as reference
    affine = imgs[0].affine
    header = imgs[0].header
    
    # Create the concatenated image
    concat_img = nib.Nifti1Image(data_concat, affine=affine, header=header)
    
    # Saving path
    output_dir = f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/concatenated_emotions_sub-{sub_str}"
    os.makedirs(output_dir, exist_ok=True)
    
    output_path = os.path.join(output_dir, f"sub-{sub_str}_allemotions.nii.gz")
    
    # Save the file
    nib.save(concat_img, output_path)
    
    print(f"File salvato in: {output_path}")
# Out:
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-01/func/concatenated_emotions_sub-01/sub-01_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-02/func/concatenated_emotions_sub-02/sub-02_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-03/func/concatenated_emotions_sub-03/sub-03_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-04/func/concatenated_emotions_sub-04/sub-04_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-05/func/concatenated_emotions_sub-05/sub-05_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-06/func/concatenated_emotions_sub-06/sub-06_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-07/func/concatenated_emotions_sub-07/sub-07_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-08/func/concatenated_emotions_sub-08/sub-08_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-09/func/concatenated_emotions_sub-09/sub-09_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-10/func/concatenated_emotions_sub-10/sub-10_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-11/func/concatenated_emotions_sub-11/sub-11_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-12/func/concatenated_emotions_sub-12/sub-12_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-13/func/concatenated_emotions_sub-13/sub-13_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-14/func/concatenated_emotions_sub-14/sub-14_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-15/func/concatenated_emotions_sub-15/sub-15_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-16/func/concatenated_emotions_sub-16/sub-16_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-17/func/concatenated_emotions_sub-17/sub-17_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-18/func/concatenated_emotions_sub-18/sub-18_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-19/func/concatenated_emotions_sub-19/sub-19_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-20/func/concatenated_emotions_sub-20/sub-20_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-21/func/concatenated_emotions_sub-21/sub-21_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-22/func/concatenated_emotions_sub-22/sub-22_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-23/func/concatenated_emotions_sub-23/sub-23_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-24/func/concatenated_emotions_sub-24/sub-24_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-25/func/concatenated_emotions_sub-25/sub-25_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-26/func/concatenated_emotions_sub-26/sub-26_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-27/func/concatenated_emotions_sub-27/sub-27_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-28/func/concatenated_emotions_sub-28/sub-28_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-29/func/concatenated_emotions_sub-29/sub-29_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-30/func/concatenated_emotions_sub-30/sub-30_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-31/func/concatenated_emotions_sub-31/sub-31_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-32/func/concatenated_emotions_sub-32/sub-32_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-33/func/concatenated_emotions_sub-33/sub-33_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-34/func/concatenated_emotions_sub-34/sub-34_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-35/func/concatenated_emotions_sub-35/sub-35_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-36/func/concatenated_emotions_sub-36/sub-36_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-37/func/concatenated_emotions_sub-37/sub-37_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-38/func/concatenated_emotions_sub-38/sub-38_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-39/func/concatenated_emotions_sub-39/sub-39_allemotions.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-40/func/concatenated_emotions_sub-40/sub-40_allemotions.nii.gz

# %%
for sub_id in range(1, 41):  
    sub_str = f"{sub_id:02d}"  
    
    # Paths of the files to concatenate (for the specific subject)
    file_paths = [
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_2_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_4_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_6_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_8_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_10_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_12_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_14_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_16_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_18_white_noise.nii.gz",
        f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/sub-{sub_str}_splitted/sub-{sub_str}_20_white_noise.nii.gz",
    ]
    
    # Load all NIfTI files
    imgs = [nib.load(f) for f in file_paths]
    
    
    # Extract the data and concatenate along the temporal axis (last axis)
    data_concat = np.concatenate([img.get_fdata() for img in imgs], axis=3)
       
    # Use the affine and header from the first file as reference
    affine = imgs[0].affine
    header = imgs[0].header
    
    
    # Create the concatenated image
    concat_img = nib.Nifti1Image(data_concat, affine=affine, header=header)
    
    output_dir = f"/Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-{sub_str}/func/concatenated_emotions_sub-{sub_str}"
    os.makedirs(output_dir, exist_ok=True)
    
    output_path = os.path.join(output_dir, f"sub-{sub_str}_whitenoise.nii.gz")
    

    nib.save(concat_img, output_path)
    
    print(f"File salvato in: {output_path}")
# Out:
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-01/func/concatenated_emotions_sub-01/sub-01_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-02/func/concatenated_emotions_sub-02/sub-02_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-03/func/concatenated_emotions_sub-03/sub-03_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-04/func/concatenated_emotions_sub-04/sub-04_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-05/func/concatenated_emotions_sub-05/sub-05_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-06/func/concatenated_emotions_sub-06/sub-06_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-07/func/concatenated_emotions_sub-07/sub-07_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-08/func/concatenated_emotions_sub-08/sub-08_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-09/func/concatenated_emotions_sub-09/sub-09_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-10/func/concatenated_emotions_sub-10/sub-10_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-11/func/concatenated_emotions_sub-11/sub-11_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-12/func/concatenated_emotions_sub-12/sub-12_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-13/func/concatenated_emotions_sub-13/sub-13_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-14/func/concatenated_emotions_sub-14/sub-14_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-15/func/concatenated_emotions_sub-15/sub-15_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-16/func/concatenated_emotions_sub-16/sub-16_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-17/func/concatenated_emotions_sub-17/sub-17_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-18/func/concatenated_emotions_sub-18/sub-18_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-19/func/concatenated_emotions_sub-19/sub-19_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-20/func/concatenated_emotions_sub-20/sub-20_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-21/func/concatenated_emotions_sub-21/sub-21_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-22/func/concatenated_emotions_sub-22/sub-22_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-23/func/concatenated_emotions_sub-23/sub-23_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-24/func/concatenated_emotions_sub-24/sub-24_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-25/func/concatenated_emotions_sub-25/sub-25_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-26/func/concatenated_emotions_sub-26/sub-26_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-27/func/concatenated_emotions_sub-27/sub-27_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-28/func/concatenated_emotions_sub-28/sub-28_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-29/func/concatenated_emotions_sub-29/sub-29_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-30/func/concatenated_emotions_sub-30/sub-30_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-31/func/concatenated_emotions_sub-31/sub-31_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-32/func/concatenated_emotions_sub-32/sub-32_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-33/func/concatenated_emotions_sub-33/sub-33_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-34/func/concatenated_emotions_sub-34/sub-34_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-35/func/concatenated_emotions_sub-35/sub-35_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-36/func/concatenated_emotions_sub-36/sub-36_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-37/func/concatenated_emotions_sub-37/sub-37_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-38/func/concatenated_emotions_sub-38/sub-38_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-39/func/concatenated_emotions_sub-39/sub-39_whitenoise.nii.gz
# File salvato in: /Users/irenesilvestro/Desktop/quinto anno uni/computational neuroscience/PROGETTO/DATA/sub-40/func/concatenated_emotions_sub-40/sub-40_whitenoise.nii.gz
